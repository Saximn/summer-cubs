# %% [markdown]
# # From chatgpt

# %%
import glob, json
import pandas as pd

# 1) Gather all FHIR JSON files
files = glob.glob("../output/fhir/*.json")

# %%
# 2) Partition them by resource type
encounters = []
observations = []
for path in files:
    with open(path) as f:
        res = json.load(f)
    rtype = res.get("resourceType")
    if rtype == "Encounter":
        encounters.append(res)
    elif rtype == "Observation":
        observations.append(res)
    # (you can extend for Patient, Location, etc.)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[6], line 6
#       4 for path in files:
#       5     with open(path) as f:
# ----> 6         res = json.load(f)
#       7     rtype = res.get("resourceType")
#       8     if rtype == "Encounter":
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)    291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\encodings\cp1252.py:23, in IncrementalDecoder.decode(self, input, final)
#      22 def decode(self, input, final=False):
# ---> 23     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 17298: character maps to <undefined>

# %%
# 3) Build an occupancy DataFrame from Encounters
records = []
for enc in encounters:
    ward = "unknown"
    # if enc["location"] exists, extract ward/location:
    if enc.get("location"):
        ward = enc["location"][0]["location"]["reference"].split("/")[-1]
    start = pd.to_datetime(enc["period"]["start"])
    end   = pd.to_datetime(enc["period"]["end"])
    records.append({"ward": ward, "start": start, "end": end})
df_enc = pd.DataFrame(records)

# %%
# 4) Expand to hourly occupancy counts
rows = []
for _, row in df_enc.iterrows():
    rng = pd.date_range(row["start"], row["end"], freq="H", closed="left")
    rows.append(pd.DataFrame({"timestamp": rng, "ward": row["ward"]}))
df_occ = pd.concat(rows, ignore_index=True)
df_occ = df_occ.groupby(["ward", "timestamp"]).size().reset_index(name="occupancy")

# %%
# 5) (Optional) Extract vitals from Observation for covariates
obs_rows = []
for obs in observations:
    pid = obs["subject"]["reference"].split("/")[-1]
    ts  = pd.to_datetime(obs["effectiveDateTime"])
    val = obs["valueQuantity"]["value"]
    code = obs["code"]["coding"][0]["code"]
    obs_rows.append({"patient": pid, "timestamp": ts, code: val})
df_obs = pd.DataFrame(obs_rows)
df_obs = df_obs.set_index("timestamp").sort_index()
# You can pivot to get wide table: df_obs.pivot_table(...)

# %%
# 6) Merge occupancy + covariates
# e.g. left-join df_occ (grouped per ward‐hour) with aggregated df_obs (e.g. mean per hour)

# 7) Add time features
df_occ["hour"]       = df_occ["timestamp"].dt.hour
df_occ["dow"]        = df_occ["timestamp"].dt.dayofweek
df_occ["is_weekend"] = df_occ["dow"].isin([5,6]).astype(int)
# and any holiday calendar you like

# 8) Final training table
# Columns: ward, timestamp, occupancy (target), plus covariates (hour, dow, is_weekend, vitals…)

df_training = df_occ  # now ready to feed into your TFT pipeline
# Save to Parquet or CSV:
df_training.to_parquet("training_data.parquet")

# %% [markdown]
# # Custom

# %%
from pandas import json_normalize
import ndjson
import pandas as pd
import json
import torch

# %%
def flatten_json(nested_json):
    out = {}

    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '_')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + str(i) + '_')
                i += 1
        else:
            out[name[:-1]] = x

    flatten(nested_json)
    return out

# %%
# 1) Gather all FHIR JSON files
files = glob.glob("../output/fhir/*.json")

# %%
# extract_fhir.py

import argparse
import glob
import json
import pandas as pd
from pathlib import Path

def load_encounters(input_dir: Path):
    """
    Read all .json files in input_dir, parse FHIR bundles,
    and collect Encounter resources with period.start/end & ward.
    """
    encounters = []
    for fp in input_dir.glob("*.json"):
        text = fp.read_text(encoding="utf-8", errors="ignore")
        bundle = json.loads(text)
        for entry in bundle.get("entry", []):
            res = entry.get("resource", {})
            if res.get("resourceType") != "Encounter":
                continue
            period = res.get("period", {})
            if "start" not in period or "end" not in period:
                continue
            # extract ward/location display (fallback to 'unknown')
            loc = res.get("location", [{}])[0].get("location", {})
            ward = loc.get("display") or loc.get("reference", "unknown").split("/")[-1]
            encounters.append({
                "start": pd.to_datetime(period["start"]),
                "end":   pd.to_datetime(period["end"]),
                "ward":  ward
            })
    return pd.DataFrame(encounters)

def build_hourly_occupancy(df_enc: pd.DataFrame):
    """
    Expand each encounter into hourly timestamps, then
    aggregate per (ward, timestamp) to count active Encounters.
    """
    rows = []
    for _, row in df_enc.iterrows():
        rng = pd.date_range(row["start"], row["end"],
                            freq="H", inclusive="left")
        df = pd.DataFrame({
            "timestamp": rng,
            "ward":      row["ward"]
        })
        rows.append(df)
    # concatenate and count
    all_hours = pd.concat(rows, ignore_index=True)
    occ = (all_hours
           .groupby(["ward", "timestamp"])
           .size()
           .reset_index(name="occupancy"))
    return occ

def main():
    IN_PATH = Path("../output/fhir")
    OUT_PATH = Path("../output/cleaned_fhir")

    # 1. Load Encounters
    df_enc = load_encounters(IN_PATH)
    if df_enc.empty:
        print("⚠️  No Encounter resources found.")
        return

    # 2. Build hourly occupancy table
    df_occ = build_hourly_occupancy(df_enc)

    # 3. (Optional) add time features
    df_occ["hour"] = df_occ["timestamp"].dt.hour
    df_occ["dow"]  = df_occ["timestamp"].dt.dayofweek
    df_occ["is_weekend"] = df_occ["dow"].isin([5,6]).astype(int)

    # 4. Write out
    OUT_PATH.parent.mkdir(parents=True, exist_ok=True)
    df_occ.to_csv("output.csv")
    print(f"→ Occupancy data written to {OUT_PATH}")

if __name__ == "__main__":
    main()
# Out:
# → Occupancy data written to ..\output\cleaned_fhir
# C:\Users\Gigabyte\AppData\Local\Temp\ipykernel_14232\3757462872.py:42: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   rng = pd.date_range(row["start"], row["end"],

# %% [markdown]
# # EDA

# %% [markdown]
# ## Structure exploration

# %%
def flatten_json(nested_json):
    out = {}

    def flatten(x, name=''):
        if isinstance(x, dict):
            for a in x:
                flatten(x[a], name + a + '_')
        elif isinstance(x, list):
            for i, a in enumerate(x):
                flatten(a, name + str(i) + '_')
        else:
            out[name[:-1]] = x

    flatten(nested_json)
    return out

# Example usage:
import json

# %%
with open(files[0]) as f:
    data = json.load(f)

flat_dict = flatten_json(data)
print(flat_dict)
# Out:
# {'resourceType': 'Bundle', 'type': 'transaction', 'entry_0_fullUrl': 'urn:uuid:4b40465b-ea68-fa3f-b224-d45cbc171913', 'entry_0_resource_resourceType': 'Patient', 'entry_0_resource_id': '4b40465b-ea68-fa3f-b224-d45cbc171913', 'entry_0_resource_meta_profile_0': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient', 'entry_0_resource_text_status': 'generated', 'entry_0_resource_text_div': '<div xmlns="http://www.w3.org/1999/xhtml">Generated by <a href="https://github.com/synthetichealth/synthea">Synthea</a>.Version identifier: c807432\n .   Person seed: 945465854560076454  Population seed: 1750493949303</div>', 'entry_0_resource_extension_0_url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race', 'entry_0_resource_extension_0_extension_0_url': 'ombCategory', 'entry_0_resource_extension_0_extension_0_valueCoding_system': 'urn:oid:2.16.840.1.113883.6.238', 'entry_0_resource_extension_0_extension_0_valueCoding_code': '2106-3', 'entry_0_resource_extension_0_extension_0_valueCoding_display': 'White', 'entry_0_resource_extension_0_extension_1_url': 'text', 'entry_0_resource_extension_0_extension_1_valueString': 'White', 'entry_0_resource_extension_1_url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity', 'entry_0_resource_extension_1_extension_0_url': 'ombCategory', 'entry_0_resource_extension_1_extension_0_valueCoding_system': 'urn:oid:2.16.840.1.113883.6.238', 'entry_0_resource_extension_1_extension_0_valueCoding_code': '2186-5', 'entry_0_resource_extension_1_extension_0_valueCoding_display': 'Not Hispanic or Latino', 'entry_0_resource_extension_1_extension_1_url': 'text', 'entry_0_resource_extension_1_extension_1_valueString': 'Not Hispanic or Latino', 'entry_0_resource_extension_2_url': 'http://hl7.org/fhir/StructureDefinition/patient-mothersMaidenName', 'entry_0_resource_extension_2_valueString': "Shay725 O'Connell601", 'entry_0_resource_extension_3_url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-birthsex', 'entry_0_resource_extension_3_valueCode': 'M', 'entry_0_resource_extension_4_url': 'http://hl7.org/fhir/StructureDefinition/patient-birthPlace', 'entry_0_resource_extension_4_valueAddress_city': 'Boston', 'entry_0_resource_extension_4_valueAddress_state': 'Massachusetts', 'entry_0_resource_extension_4_valueAddress_country': 'US', 'entry_0_resource_extension_5_url': 'http://synthetichealth.github.io/synthea/disability-adjusted-life-years', 'entry_0_resource_extension_5_valueDecimal': 0.0008823084504462283, 'entry_0_resource_extension_6_url': 'http://synthetichealth.github.io/synthea/quality-adjusted-life-years', 'entry_0_resource_extension_6_valueDecimal': 12.999117691549554, 'entry_0_resource_identifier_0_system': 'https://github.com/synthetichealth/synthea', 'entry_0_resource_identifier_0_value': '4b40465b-ea68-fa3f-b224-d45cbc171913', 'entry_0_resource_identifier_1_type_coding_0_system': 'http://terminology.hl7.org/CodeSystem/v2-0203', 'entry_0_resource_identifier_1_type_coding_0_code': 'MR', 'entry_0_resource_identifier_1_type_coding_0_display': 'Medical Record Number', 'entry_0_resource_identifier_1_type_text': 'Medical Record Number', 'entry_0_resource_identifier_1_system': 'http://hospital.smarthealthit.org', 'entry_0_resource_identifier_1_value': '4b40465b-ea68-fa3f-b224-d45cbc171913', 'entry_0_resource_identifier_2_type_coding_0_system': 'http://terminology.hl7.org/CodeSystem/v2-0203', 'entry_0_resource_identifier_2_type_coding_0_code': 'SS', 'entry_0_resource_identifier_2_type_coding_0_display': 'Social Security Number', 'entry_0_resource_identifier_2_type_text': 'Social Security Number', 'entry_0_resource_identifier_2_system': 'http://hl7.org/fhir/sid/us-ssn', 'entry_0_resource_identifier_2_value': '999-83-8497', 'entry_0_resource_name_0_use': 'official', 'entry_0_resource_name_0_family': 'Lueilwitz711', 'entry_0_resource_name_0_given_0': 'Arnoldo445', 'entry_0_resource_name_0_given_1': 'Cameron381', 'entry_0_resource_telecom_0_system': 'phone', 'entry_0_resou ...

# %%
data.keys()
# Out:
# dict_keys(['resourceType', 'type', 'entry'])

# %%
len(data["entry"])
# Out:
# 352

# %% [markdown]
# so this person has 352 entries

# %%
data["entry"][0].keys()
# Out:
# dict_keys(['fullUrl', 'resource', 'request'])

# %%
data["entry"][0]["fullUrl"]
# Out:
# 'urn:uuid:4b40465b-ea68-fa3f-b224-d45cbc171913'

# %%
data["entry"][0]["request"]
# Out:
# {'method': 'POST', 'url': 'Patient'}

# %%
methods = {}
all_url = {}
for i in range (352):
    methods[data["entry"][i]["request"]["method"]] = methods.get(data["entry"][i]["request"]["method"], 0) + 1
    all_url[data["entry"][i]["request"]["url"]] = all_url.get(data["entry"][i]["request"]["url"], 0) + 1

# %%
methods
# Out:
# {'POST': 352}

# %%
all_url # data["entry"][i]["request"]["url"] is the url of the request
# Out:
# {'Patient': 1,
#  'Encounter': 20,
#  'Condition': 11,
#  'DiagnosticReport': 26,
#  'DocumentReference': 20,
#  'Claim': 26,
#  'ExplanationOfBenefit': 26,
#  'MedicationRequest': 6,
#  'CareTeam': 3,
#  'CarePlan': 3,
#  'Observation': 116,
#  'Immunization': 21,
#  'Procedure': 52,
#  'SupplyDelivery': 12,
#  'Medication': 3,
#  'MedicationAdministration': 3,
#  'Device': 1,
#  'ImagingStudy': 1,
#  'Provenance': 1}

# %% [markdown]
# and those are the data

# %% [markdown]
# for each type in url, find information about it

# %%
from collections import defaultdict

report_type_to_index = defaultdict(list)
for i, entry in enumerate(data["entry"]):
    if "request" in entry and "url" in entry["request"]:
        url = entry["request"]["url"]
        report_type = url.split("/")[-1]  # Extract the last part of the URL
        report_type_to_index[report_type].append(i)

# %%
none_key_exists = None in report_type_to_index
print("Is there a None key in report_type_to_index?", none_key_exists)
# Out:
# Is there a None key in report_type_to_index? False

# %%
patient_index = report_type_to_index.get("Patient")

# %%
print(data["entry"][0]["resource"].keys())
# Out:
# dict_keys(['resourceType', 'id', 'meta', 'text', 'extension', 'identifier', 'name', 'telecom', 'gender', 'birthDate', 'address', 'maritalStatus', 'multipleBirthBoolean', 'communication'])

# %%
for report_type in all_url.keys():
    print("=" * 20)
    print(f"analyzing {report_type}")
    type_index = report_type_to_index.get(report_type)
    for keys in data["entry"][type_index[0]]["resource"].keys():
        print(f"  {keys} : {data['entry'][type_index[0]]['resource'][keys]}")
    print("=" * 20)
# Out:
# ====================
# analyzing Patient
#   resourceType : Patient
#   id : 4b40465b-ea68-fa3f-b224-d45cbc171913
#   meta : {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']}
#   text : {'status': 'generated', 'div': '<div xmlns="http://www.w3.org/1999/xhtml">Generated by <a href="https://github.com/synthetichealth/synthea">Synthea</a>.Version identifier: c807432\n .   Person seed: 945465854560076454  Population seed: 1750493949303</div>'}
#   extension : [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race', 'extension': [{'url': 'ombCategory', 'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238', 'code': '2106-3', 'display': 'White'}}, {'url': 'text', 'valueString': 'White'}]}, {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity', 'extension': [{'url': 'ombCategory', 'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238', 'code': '2186-5', 'display': 'Not Hispanic or Latino'}}, {'url': 'text', 'valueString': 'Not Hispanic or Latino'}]}, {'url': 'http://hl7.org/fhir/StructureDefinition/patient-mothersMaidenName', 'valueString': "Shay725 O'Connell601"}, {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-birthsex', 'valueCode': 'M'}, {'url': 'http://hl7.org/fhir/StructureDefinition/patient-birthPlace', 'valueAddress': {'city': 'Boston', 'state': 'Massachusetts', 'country': 'US'}}, {'url': 'http://synthetichealth.github.io/synthea/disability-adjusted-life-years', 'valueDecimal': 0.0008823084504462283}, {'url': 'http://synthetichealth.github.io/synthea/quality-adjusted-life-years', 'valueDecimal': 12.999117691549554}]
#   identifier : [{'system': 'https://github.com/synthetichealth/synthea', 'value': '4b40465b-ea68-fa3f-b224-d45cbc171913'}, {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203', 'code': 'MR', 'display': 'Medical Record Number'}], 'text': 'Medical Record Number'}, 'system': 'http://hospital.smarthealthit.org', 'value': '4b40465b-ea68-fa3f-b224-d45cbc171913'}, {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203', 'code': 'SS', 'display': 'Social Security Number'}], 'text': 'Social Security Number'}, 'system': 'http://hl7.org/fhir/sid/us-ssn', 'value': '999-83-8497'}]
#   name : [{'use': 'official', 'family': 'Lueilwitz711', 'given': ['Arnoldo445', 'Cameron381']}]
#   telecom : [{'system': 'phone', 'value': '555-625-8694', 'use': 'home'}]
#   gender : male
#   birthDate : 2011-06-16
#   address : [{'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/geolocation', 'extension': [{'url': 'latitude', 'valueDecimal': 42.60533255531487}, {'url': 'longitude', 'valueDecimal': -70.74033528303094}]}], 'line': ['877 Harris Mall Suite 51'], 'city': 'Essex', 'state': 'MA', 'postalCode': '01929', 'country': 'US'}]
#   maritalStatus : {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v3-MaritalStatus', 'code': 'S', 'display': 'Never Married'}], 'text': 'Never Married'}
#   multipleBirthBoolean : False
#   communication : [{'language': {'coding': [{'system': 'urn:ietf:bcp:47', 'code': 'en-US', 'display': 'English (United States)'}], 'text': 'English (United States)'}}]
# ====================
# ====================
# analyzing Encounter
#   resourceType : Encounter
#   id : ec9b24ff-7b15-dd4d-3e00-345cecda85d2
#   meta : {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter']}
#   identifier : [{'use': 'official', 'system': 'https://github.com/synthetichealth/synthea', 'value': 'ec9b24ff-7b15-dd4d-3e00-345cecda85d2'}]
#   status : finished
#   class : {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode', 'code': 'AMB'}
#   type : [{'coding': [{'system': 'http://snomed.info/sct', 'code': '410620009', 'display': 'Well child visit (procedure)'}], 'text': 'Well child visit (procedure)'}]
#   subject : {'reference': 'urn:uuid:4b40465b-ea68-fa3f-b224-d45cbc171913', 'display': 'Arnoldo445 Cameron381 Lueilwitz711'}
#   participant : [{'type': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v3-ParticipationType', 'code': 'PPRF', 'display': 'primary performer'}], 'text': 'primary performer'}], 'period': {'start': '2014-11-20T13:53:15+07:00', 'end': '2014-11-20T14:08:15+07:00'}, 'individual': {'reference': 'Practitioner?identifier=http://hl7.org/fhir/sid/us-npi|9999951491', 'display': 'Dr. Marcela739 CasÃ¡rez469'}}]
#   period : {'start': '2014-11-20T13:53:15+07:00', 'end': '2014-11-20T14:08:15+07:00'}
#   location : [{'location': {'reference': 'Location?identifier=https://github.com/synthetichealth/synthea|187ffa22-f0d4-3b78-9d80-cf3edbf9fe28', 'display': 'CAPE ANN MEDICAL CENTER LLC'}}]
#   serviceProvider : {'reference': 'Organization?identifier=https://github.com/synthetichealth/synthea|c67ca7ed-4769-3b6c-a0a9-993f1227ff10', 'display': 'CAPE ANN MEDICAL CENTER LLC'}
# ====================
# ====================
# analyzing Condition
#   resourceType : Condition
#   id : 96b655d9-ead0-025e-35f4-5f447c3ac20f
#   meta : {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']}
#   clinicalStatus : {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical', 'code': 'resolved'}]}
#   verificationStatus : {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status', 'code': 'confirmed'}]}
#   category : [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category', 'code': 'encounter-diagnosis', 'display': 'Encounter Diagnosis'}]}]
#   code : {'coding': [{'system': 'http://snomed.info/sct', 'code': '314529007', 'display': 'Medication review due (situation)'}], 'text': 'Medication review due (situation)'}
#   subject : {'reference': 'urn:uuid:4b40465b-ea68-fa3f-b224-d45cbc171913'}
#   encounter : {'reference': 'urn:uuid:ec9b24ff-7b15-dd4d-3e00-345cecda85d2'}
#   onsetDateTime : 2014-11-20T13:53:15+07:00
#   abatementDateTime : 2017-06-01T13:53:15+07:00
#   recordedDate : 2014-11-20T13:53:15+07:00
# ====================
# ====================
# analyzing DiagnosticReport
#   resourceType : DiagnosticReport
#   id : b5d21f47-0a93-1765-14cc-d32ccca2b875
#   meta : {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-diagnosticreport-note']}
#   status : final
#   category : [{'coding': [{'system': 'http://loinc.org', 'code': '34117-2', 'display': 'History and physical note'}, {'system': 'http://loinc.org', 'code': '51847-2', 'display': 'Evaluation + Plan note'}]}]
#   code : {'coding': [{'system': 'http://loinc.org', 'code': '34117-2', 'display': 'History and physical note'}, {'system': 'http://loinc.org', 'code': '51847-2', 'display': 'Evaluation + Plan note'}]}
#   subject : {'reference': 'urn:uuid:4b40465b-ea68-fa3f-b224-d45cbc171913'}
#   encounter : {'reference': 'urn:uuid:ec9b24ff-7b15-dd4d-3e00-345cecda85d2'}
#   effectiveDateTime : 2014-11-20T13:53:15+07:00
#   issued : 2014-11-20T13:53:15.340+07:00
#   performer : [{'reference': 'Practitioner?identifier=http://hl7.org/fhir/sid/us-npi|9999951491', 'display': 'Dr. Marcela739 CasÃ¡rez469'}]
#   presentedForm : [{'contentType': 'text/plain; charset=utf-8', 'data': '...'}]
# ====================
# ====================
# analyzing DocumentReference
#   resourceType : DocumentReference
#   id : ed78dbe4-77a3-842a-6a81-56dc4d42b23b
#   meta : {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-documentreference']}
#   identifier : [{'system': 'urn:ietf:rfc:3986', 'value': 'urn:uuid:b5d21f47-0a93-1765-14cc-d32ccca2b875'}]
#   status : superseded
#   type : {'coding': [{'system': 'http://loinc.org', 'code': '34117-2', 'display': 'History and physical note'}, {'system': 'http://loinc.org', 'code': '51847-2', 'display': 'Evaluation + Plan note'}]}
#   category : [{'coding': [{'system': 'http://hl7.org/fhir/us/core/CodeSystem/us-core-documentreference-category', 'code': 'clinical-note', 'display': 'Clinical Note'}]}]
#   subject : {'reference': 'urn:uuid:4b40465b-ea68-fa3f-b224-d45cbc171913'}
#   date : 2014-11-20T13:53:15.340+07:00
#   author : [{'reference': 'Practitioner?identifier=http://hl7.org/fhir/sid/us-npi|9999951491', 'display': 'Dr. Marcela739 CasÃ¡rez469'}]
#   custodian : {'reference': 'Organization?identifier=https://github.com/synthetichealth/synthea|c67ca7ed-4769-3b6c-a0a9-993f1227ff10', 'display': 'CAPE ANN MEDICAL CENTER LLC'}
#   content : [{'attachment': {'contentType': 'text/plain; charset=utf-8', 'data': '...'}, 'format': {'system': 'http://ihe.net/fhir/ihe.formatcode.fhir/CodeSystem/formatcode', 'code': 'urn:ihe:iti:xds:2017:mimeTypeSufficient', 'display': 'mimeType Sufficient'}}]
#   context : {'encounter': [{'reference': 'urn:uuid:ec9b24ff-7b15-dd4d-3e00-345cecda85d2'}], 'period': {'start': '2014-11-20T13:53:15+07:00', 'end': '2014-11-20T14:08:15+07:00'}}
# ====================
# ====================
# analyzing Claim
#   resourceType : Claim
#   id : c43cfa89-dc00-f761-c544-037851a7a4e9
#   status : active
#   type : {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/claim-type', 'code': 'professional'}]}
#   use : claim
#   patient : {'reference': 'urn:uuid:4b40465b-ea68-fa3f-b224-d45cbc171913', 'display': 'Arnoldo445 Lueilwitz711'}
#   billablePeriod : {'start': '2014-11-20T13:53:15+07:00', 'end': '2014-11-20T14:08:15+07:00'}
#   created : 2014-11-20T14:08:15+07:00
#   provider : {'reference': 'Organization?identifier=https://github.com/synthetichealth/synthea|c67ca7ed-4769-3b6c-a0a9-993f1227ff10', 'display': 'CAPE ANN MEDICAL CENTER LLC'}
#   priority : {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/processpriority', 'code': 'normal'}]}
#   facility : {'reference': 'Location?identifier=https://github.com/synthetichealth/synthea|187ffa22-f0d4-3b78-9d80-cf3edbf9fe28', 'display': 'CAPE ANN MEDICAL CENTER LLC'}
#   diagnosis : [{'sequence': 1, 'diagnosisReference': {'reference': 'urn:uuid:96b655d9-ead0-025e-35f4-5f447c3ac20f'}}]
#   insurance : [{'sequence': 1, 'focal': True, 'coverage': {'display': 'UnitedHealthcare'}}]
#   item : [{'sequence': 1, 'productOrService': {'coding': [{'system': 'http://snomed.info/sct', 'code': '410620009', 'display': 'Well child visit (procedure)'}], 'text': 'Well child visit (procedure)'}, 'encounter': [{'reference': 'urn:uuid:ec9b24ff-7b15-dd4d-3e00-345cecda85d2'}]}, {'sequence': 2, 'diagnosisSequence': [1], 'productOrService': {'coding': [{'system': 'http://snomed.info/sct', 'code': '314529007', 'display': 'Medication review due (situation)'}], 'text': 'Medication review due (situation)'}}]
#   total : {'value': 568.2, 'currency': 'USD'}
# ====================
# ====================
# analyzing ExplanationOfBenefit
#   resourceType : ExplanationOfBenefit
#   id : 1d7154bf-093c-384f-0333-66f3b08f149b
#   contained : [{'resourceType': 'ServiceRequest', 'id': 'referral', 'status': 'completed', 'intent': 'order', 'subject': {'reference': 'urn:uuid:4b40465b-ea68-fa3f-b224-d45cbc171913'}, 'requester': {'reference': 'Practitioner?identifier=http://hl7.org/fhir/sid/us-npi|9999951491'}, 'performer': [{'reference': 'Practitioner?identifier=http://hl7.org/fhir/sid/us-npi|9999951491'}]}, {'resourceType': 'Coverage', 'id': 'coverage', 'status': 'active', 'type': {'text': 'UnitedHealthcare'}, 'beneficiary': {'reference': 'urn:uuid:4b40465b-ea68-fa3f-b224-d45cbc171913'}, 'payor': [{'display': 'UnitedHealthcare'}]}]
#   identifier : [{'system': 'https://bluebutton.cms.gov/resources/variables/clm_id', 'value': 'c43cfa89-dc00-f761-c544-037851a7a4e9'}, {'system': 'https://bluebutton.cms.gov/resources/identifier/claim-group', 'value': '99999999999'}]
#   status : active
#   type : {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/claim-type', 'code': 'professional'}]}
#   use : claim
#   patient : {'reference': 'urn:uuid:4b40465b-ea68-fa3f-b224-d45cbc171913'}
#   billablePeriod : {'start': '2014-11-20T14:08:15+07:00', 'end': '2015-11-20T14:08:15+07:00'}
#   created : 2014-11-20T14:08:15+07:00
#   insurer : {'display': 'UnitedHealthcare'}
#   provider : {'reference': 'Practitioner?identifier=http://hl7.org/fhir/sid/us-npi|9999951491'}
#   referral : {'reference': '#referral'}
#   facility : {'reference': 'Location?identifier=https://github.com/synthetichealth/synthea|187ffa22-f0d4-3b78-9d80-cf3edbf9fe28', 'display': 'CAPE ANN MEDICAL CENTER LLC'}
#   claim : {'reference': 'urn:uuid:c43cfa89-dc00-f761-c544-037851a7a4e9'}
#   outcome : complete
#   careTeam : [{'sequence': 1, 'provider': {'reference': 'Practitioner?identifier=http://hl7.org/fhir/sid/us-npi|9999951491'}, 'role': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/claimcareteamrole', 'code': 'primary', 'display': 'Primary provider'}]}}]
#   diagnosis : [{'sequence': 1, 'diagnosisReference': {'reference': 'urn:uuid:96b655d9-ead0-025e-35f4-5f447c3ac20f'}, 'type': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/ex-diagnosistype', 'code': 'principal'}]}]}]
#   insurance : [{'focal': True, 'coverage': {'reference': '#coverage', 'display': 'UnitedHealthcare'}}]
#   item : [{'sequence': 1, 'category': {'coding': [{'system': 'https://bluebutton.cms.gov/resources/variables/line_cms_type_srvc_cd', 'code': '1', 'display': 'Medical care'}]}, 'productOrService': {'coding': [{'system': 'http://snomed.info/sct', 'code': '410620009', 'display': 'Well child visit (procedure)'}], 'text': 'Well child visit (procedure)'}, 'servicedPeriod': {'start': '2014-11-20T13:53:15+07:00', 'end': '2014-11-20T14:08:15+07:00'}, 'locationCodeableConcept': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/ex-serviceplace', 'code': '19', 'display': 'Off Campus-Outpatient Hospital'}]}, 'encounter': [{'reference': 'urn:uuid:ec9b24ff-7b15-dd4d-3e00-345cecda85d2'}]}, {'sequence': 2, 'diagnosisSequence': [1], 'category': {'coding': [{'system': 'https://bluebutton.cms.gov/resources/variables/line_cms_type_srvc_cd', 'code': '1', 'display': 'Medical care'}]}, 'productOrService': {'coding': [{'system': 'http://snomed.info/sct', 'code': '314529007', 'display': 'Medication review due (situation)'}], 'text': 'Medication review due (situation)'}, 'servicedPeriod': {'start': '2014-11-20T13:53:15+07:00', 'end': '2014-11-20T14:08:15+07:00'}, 'locationCodeableConcept': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/ex-serviceplace', 'code': '19', 'display': 'Off Campus-Outpatient Hospital'}]}}]
#   total : [{'category': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/adjudication', 'code': 'submitted', 'display': 'Submitted Amount'}], 'text': 'Submitted Amount'}, 'amount': {'value': 568.2, 'currency': 'USD'}}]
#   payment : {'amount': {'value': 0.0, 'currency': 'USD'}}
# ====================
# ====================
# analyzing MedicationRequest
#   resourceType : MedicationRequest
#   id : c94ed6db-eb7f-2bdb-81ed-615b0eff2582
#   meta : {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-medicationrequest']}
#   status : completed
#   intent : order
#   category : [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/medicationrequest-category', 'code': 'community', 'display': 'Community'}], 'text': 'Community'}]
#   medicationCodeableConcept : {'coding': [{'system': 'http://www.nlm.nih.gov/research/umls/rxnorm', 'code': '313782', 'display': 'Acetaminophen 325 MG Oral Tablet'}], 'text': 'Acetaminophen 325 MG Oral Tablet'}
#   subject : {'reference': 'urn:uuid:4b40465b-ea68-fa3f-b224-d45cbc171913'}
#   encounter : {'reference': 'urn:uuid:10180a1d-0587-e304-00b6-0876c5512ac9'}
#   authoredOn : 2015-11-24T03:53:15+07:00
#   requester : {'reference': 'Practitioner?identifier=http://hl7.org/fhir/sid/us-npi|9999987297', 'display': 'Dr. Madelaine318 Walker122'}
#   reasonReference : [{'reference': 'urn:uuid:8d09d0df-6708-3d90-bd5a-5a39210f5d78', 'display': 'Acute bronchitis (disorder)'}]
# ====================
# ====================
# analyzing CareTeam
#   resourceType : CareTeam
#   id : e4e2b31c-4bee-c1e4-5890-fc9904310a54
#   meta : {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-careteam']}
#   status : inactive
#   subject : {'reference': 'urn:uuid:4b40465b-ea68-fa3f-b224-d45cbc171913'}
#   encounter : {'reference': 'urn:uuid:10180a1d-0587-e304-00b6-0876c5512ac9'}
#   period : {'start': '2015-11-24T03:53:15+07:00', 'end': '2016-05-26T13:53:15+07:00'}
#   participant : [{'role': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '116154003', 'display': 'Patient'}], 'text': 'Patient'}], 'member': {'reference': 'urn:uuid:4b40465b-ea68-fa3f-b224-d45cbc171913', 'display': 'Arnoldo445 Cameron381 Lueilwitz711'}}, {'role': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '223366009', 'display': 'Healthcare professional (occupation)'}], 'text': 'Healthcare professional (occupation)'}], 'member': {'reference': 'Practitioner?identifier=http://hl7.org/fhir/sid/us-npi|9999987297', 'display': 'Dr. Madelaine318 Walker122'}}, {'role': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '224891009', 'display': 'Healthcare services (qualifier value)'}], 'text': 'Healthcare services (qualifier value)'}], 'member': {'reference': 'Organization?identifier=https://github.com/synthetichealth/synthea|af8566eb-8918-3ec7-ba44-92b6a2cf8097', 'display': 'NORTH SHORE MEDICAL CENTER INC'}}]
#   managingOrganization : [{'reference': 'Organization?identifier=https://github.com/synthetichealth/synthea|af8566eb-8918-3ec7-ba44-92b6a2cf8097', 'display': 'NORTH SHORE MEDICAL CENTER INC'}]
# ====================
# ====================
# analyzing CarePlan
#   resourceType : CarePlan
#   id : 2b242fe3-8a76-3f4d-9588-92df34479220
#   meta : {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-careplan']}
#   text : {'status': 'generated', 'div': '<div xmlns="http://www.w3.org/1999/xhtml">Care Plan for Respiratory therapy (procedure).<br/>Activities: <ul><li>Respiratory therapy (procedure)</li><li>Respiratory therapy (procedure)</li></ul></div>'}
#   status : completed
#   intent : order
#   category : [{'coding': [{'system': 'http://hl7.org/fhir/us/core/CodeSystem/careplan-category', 'code': 'assess-plan'}]}, {'coding': [{'system': 'http://snomed.info/sct', 'code': '53950000', 'display': 'Respiratory therapy (procedure)'}], 'text': 'Respiratory therapy (procedure)'}]
#   subject : {'reference': 'urn:uuid:4b40465b-ea68-fa3f-b224-d45cbc171913'}
#   encounter : {'reference': 'urn:uuid:10180a1d-0587-e304-00b6-0876c5512ac9'}
#   period : {'start': '2015-11-24T03:53:15+07:00', 'end': '2016-05-26T13:53:15+07:00'}
#   careTeam : [{'reference': 'urn:uuid:e4e2b31c-4bee-c1e4-5890-fc9904310a54'}]
#   activity : [{'detail': {'code': {'coding': [{'system': 'http://snomed.info/sct', 'code': '304510005', 'display': 'Recommendation to avoid exercise (procedure)'}], 'text': 'Recommendation to avoid exercise (procedure)'}, 'status': 'completed', 'location': {'display': 'NORTH SHORE MEDICAL CENTER INC'}}}, {'detail': {'code': {'coding': [{'system': 'http://snomed.info/sct', 'code': '371605008', 'display': 'Deep breathing and coughing exercises (regime/therapy)'}], 'text': 'Deep breathing and coughing exercises (regime/therapy)'}, 'status': 'completed', 'location': {'display': 'NORTH SHORE MEDICAL CENTER INC'}}}]
# ====================
# ====================
# analyzing Observation
#   resourceType : Observation
#   id : d2f20e62-493d-2041-f898-aa1a97c299ff
#   meta : {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-height']}
#   status : final
#   category : [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category', 'code': 'vital-signs', 'display': 'Vital signs'}]}]
#   code : {'coding': [{'system': 'http://loinc.org', 'code': '8302-2', 'display': 'Body Height'}], 'text': 'Body Height'}
#   subject : {'reference': 'urn:uuid:4b40465b-ea68-fa3f-b224-d45cbc171913'}
#   encounter : {'reference': 'urn:uuid:93c3ad96-ca72-b5be-8288-b125d6b42dad'}
#   effectiveDateTime : 2016-05-26T13:53:15+07:00
#   issued : 2016-05-26T13:53:15.340+07:00
#   valueQuantity : {'value': 107, 'unit': 'cm', 'system': 'http://unitsofmeasure.org', 'code': 'cm'}
# ====================
# ====================
# analyzing Immunization
#   resourceType : Immunization
#   id : f0da539c-c415-f2af-0788-6a09c807884e
#   meta : {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-immunization']}
#   status : completed
#   vaccineCode : {'coding': [{'system': 'http://hl7.org/fhir/sid/cvx', 'code': '21', 'display': 'varicella'}], 'text': 'varicella'}
#   patient : {'reference': 'urn:uuid:4b40465b-ea68-fa3f-b224-d45cbc171913'}
#   encounter : {'reference': 'urn:uuid:93c3ad96-ca72-b5be-8288-b125d6b42dad'}
#   occurrenceDateTime : 2016-05-26T13:53:15+07:00
#   primarySource : True
#   location : {'reference': 'Location?identifier=https://github.com/synthetichealth/synthea|187ffa22-f0d4-3b78-9d80-cf3edbf9fe28', 'display': 'CAPE ANN MEDICAL CENTER LLC'}
# ====================
# ====================
# analyzing Procedure
#   resourceType : Procedure
#   id : 42235c2c-780d-fd81-3a94-79e72abd44d8
#   meta : {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-procedure']}
#   status : completed
#   code : {'coding': [{'system': 'http://snomed.info/sct', 'code': '288086009', 'display': 'Suture open wound (procedure)'}], 'text': 'Suture open wound (procedure)'}
#   subject : {'reference': 'urn:uuid:4b40465b-ea68-fa3f-b224-d45cbc171913'}
#   encounter : {'reference': 'urn:uuid:63ff1421-019f-18a0-8d43-6733a8468f56'}
#   performedPeriod : {'start': '2016-09-11T13:53:15+07:00', 'end': '2016-09-11T14:09:00+07:00'}
#   location : {'reference': 'Location?identifier=https://github.com/synthetichealth/synthea|b64fdbb3-9be7-317c-a90d-fa24b912c836', 'display': 'BLUEBERRY HILL REHABILITATION AND HEALTHCARE CTR'}
#   reasonReference : [{'reference': 'urn:uuid:b62d3389-83a8-a3eb-88b7-cf89ae842b05', 'display': 'Laceration of thigh (disorder)'}]
# ====================
# ====================
# analyzing SupplyDelivery
#   resourceType : SupplyDelivery
#   id : fd86785a-61be-7e81-0a5b-5cf399410422
#   status : completed
#   patient : {'reference': 'urn:uuid:4b40465b-ea68-fa3f-b224-d45cbc171913'}
#   type : {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/supply-item-type', 'code': 'device', 'display': 'Device'}]}
#   suppliedItem : {'quantity': {'value': 1}, 'itemCodeableConcept': {'coding': [{'system': 'http://snomed.info/sct', 'code': '277183007', 'display': 'Dental equipment (physical object)'}], 'text': 'Dental equipment (physical object)'}}
#   occurrenceDateTime : 2018-06-14T14:53:31+07:00
# ====================
# ====================
# analyzing Medication
#   resourceType : Medication
#   id : c7211981-8756-d61a-edb1-c6891e15323b
#   meta : {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-medication']}
#   code : {'coding': [{'system': 'http://www.nlm.nih.gov/research/umls/rxnorm', 'code': '1535362', 'display': 'sodium fluoride 0.0272 MG/MG Oral Gel'}], 'text': 'sodium fluoride 0.0272 MG/MG Oral Gel'}
#   status : active
# ====================
# ====================
# analyzing MedicationAdministration
#   resourceType : MedicationAdministration
#   id : 38a48679-c0fe-287e-ecc2-e1733182c2c0
#   status : completed
#   medicationCodeableConcept : {'coding': [{'system': 'http://www.nlm.nih.gov/research/umls/rxnorm', 'code': '1535362', 'display': 'sodium fluoride 0.0272 MG/MG Oral Gel'}], 'text': 'sodium fluoride 0.0272 MG/MG Oral Gel'}
#   subject : {'reference': 'urn:uuid:4b40465b-ea68-fa3f-b224-d45cbc171913'}
#   context : {'reference': 'urn:uuid:ab627a07-6655-858c-9cd3-335a212a833c'}
#   effectiveDateTime : 2018-06-14T16:55:33+07:00
#   reasonCode : [{'coding': [{'system': 'http://snomed.info/sct', 'code': '103697008', 'display': 'Patient referral for dental care (procedure)'}], 'text': 'Patient referral for dental care (procedure)'}]
# ====================
# ====================
# analyzing Device
#   resourceType : Device
#   id : 5bda906b-2e60-9389-8fb4-a4650017ee5a
#   meta : {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-implantable-device']}
#   udiCarrier : [{'deviceIdentifier': '26787934253011', 'carrierHRF': '(01)26787934253011(11)250410(17)500425(10)19756(21)3092416169'}]
#   status : active
#   distinctIdentifier : 26787934253011
#   manufactureDate : 2025-04-10T15:47:02+07:00
#   expirationDate : 2050-04-25T15:47:02+07:00
#   lotNumber : 19756
#   serialNumber : 3092416169
#   deviceName : [{'name': 'Dental x-ray system (physical object)', 'type': 'user-friendly-name'}]
#   type : {'coding': [{'system': 'http://snomed.info/sct', 'code': '706298007', 'display': 'Dental x-ray system (physical object)'}], 'text': 'Dental x-ray system (physical object)'}
#   patient : {'reference': 'urn:uuid:4b40465b-ea68-fa3f-b224-d45cbc171913'}
# ====================
# ====================
# analyzing ImagingStudy
#   resourceType : ImagingStudy
#   id : ae2124e2-a0c5-1399-c73b-29ab025efe20
#   identifier : [{'use': 'official', 'system': 'urn:ietf:rfc:3986', 'value': 'urn:oid:1.2.840.99999999.13646384.1746089222340'}]
#   status : available
#   subject : {'reference': 'urn:uuid:4b40465b-ea68-fa3f-b224-d45cbc171913'}
#   encounter : {'reference': 'urn:uuid:4f30ead1-993b-34f0-0c8c-0d456284f1fb'}
#   started : 2025-05-01T15:47:02+07:00
#   numberOfSeries : 1
#   numberOfInstances : 1
#   procedureCode : [{'coding': [{'system': 'http://snomed.info/sct', 'code': '241046008', 'display': 'Dental plain X-ray bitewing (procedure)'}], 'text': 'Dental plain X-ray bitewing (procedure)'}]
#   location : {'reference': 'Location?identifier=https://github.com/synthetichealth/synthea|956c981c-5bbc-3bac-b136-d53e114cc33f', 'display': 'NORTH SHORE MEDICAL CENTER INC'}
#   series : [{'uid': '1.2.840.99999999.1.57683769.1746089222340', 'number': 1, 'modality': {'system': 'http://dicom.nema.org/medical/dicom/current/output/chtml/part16/sect_CID_29.html', 'code': 'DX', 'display': 'Digital Radiography'}, 'numberOfInstances': 1, 'bodySite': {'system': 'http://snomed.info/sct', 'code': '700016008', 'display': 'Structure of region of internal part of mouth (body structure)'}, 'started': '2025-05-01T15:47:02+07:00', 'instance': [{'uid': '1.2.840.99999999.1.1.92571190.1746089222340', 'sopClass': {'system': 'urn:ietf:rfc:3986', 'code': 'urn:oid:1.2.840.10008.5.1.4.1.1.1.3'}, 'number': 1, 'title': 'Digital Intra-Oral X-Ray Image'}]}]
# ====================
# ====================
# analyzing Provenance
#   resourceType : Provenance
#   id : 1f3576db-ea28-c1cf-04f7-88de27fb061b
#   meta : {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-provenance']}
#   target : [{'reference': 'urn:uuid:4b40465b-ea68-fa3f-b224-d45cbc171913'}, {'reference': 'urn:uuid:ec9b24ff-7b15-dd4d-3e00-345cecda85d2'}, {'reference': 'urn:uuid:96b655d9-ead0-025e-35f4-5f447c3ac20f'}, {'reference': 'urn:uuid:b5d21f47-0a93-1765-14cc-d32ccca2b875'}, {'reference': 'urn:uuid:ed78dbe4-77a3-842a-6a81-56dc4d42b23b'}, {'reference': 'urn:uuid:c43cfa89-dc00-f761-c544-037851a7a4e9'}, {'reference': 'urn:uuid:1d7154bf-093c-384f-0333-66f3b08f149b'}, {'reference': 'urn:uuid:10180a1d-0587-e304-00b6-0876c5512ac9'}, {'reference': 'urn:uuid:8d09d0df-6708-3d90-bd5a-5a39210f5d78'}, {'reference': 'urn:uuid:c94ed6db-eb7f-2bdb-81ed-615b0eff2582'}, {'reference': 'urn:uuid:a01c6305-57be-54f3-7110-0cd590649891'}, {'reference': 'urn:uuid:e8f0a468-5386-57d6-0a14-dc222aab1633'}, {'reference': 'urn:uuid:e4e2b31c-4bee-c1e4-5890-fc9904310a54'}, {'reference': 'urn:uuid:2b242fe3-8a76-3f4d-9588-92df34479220'}, {'reference': 'urn:uuid:3dd0df2d-fda0-c780-7fef-9d23656c4b9f'}, {'reference': 'urn:uuid:00897369-e365-3d56-5caa-6d7ad954e894'}, {'reference': 'urn:uuid:e4c68398-1782-157d-6201-868308fa7a4f'}, {'reference': 'urn:uuid:d5b4cfa8-3b93-59f4-67d0-ac93cdf28805'}, {'reference': 'urn:uuid:93c3ad96-ca72-b5be-8288-b125d6b42dad'}, {'reference': 'urn:uuid:d2f20e62-493d-2041-f898-aa1a97c299ff'}, {'reference': 'urn:uuid:af99edd4-e655-0cbb-0b08-22f759439352'}, {'reference': 'urn:uuid:91ac600d-433a-b941-be92-eadc395a204e'}, {'reference': 'urn:uuid:75ebd4f1-39c0-cd29-7efb-037b42a3f80a'}, {'reference': 'urn:uuid:3825ecfd-a72c-da6c-e12b-90b37e374607'}, {'reference': 'urn:uuid:0d0dc551-7b55-bc1e-8ec5-e9dd6b3f071b'}, {'reference': 'urn:uuid:cc46f66c-09ff-44cc-5905-af8535fc29a4'}, {'reference': 'urn:uuid:1d130cc6-0e0e-5f2f-0d73-d7e9115e27b3'}, {'reference': 'urn:uuid:0305cc29-3a91-5491-0f40-35adc29dff34'}, {'reference': 'urn:uuid:f0da539c-c415-f2af-0788-6a09c807884e'}, {'reference': 'urn:uuid:44aca74a-7520-f899-b768-ebf3cfc94ded'}, {'reference': 'urn:uuid:7a367519-ad95-e08d-69a3-9f1f06c2798a'}, {'reference': 'urn:uuid:0f3175b2-50d0-a598-d71f-335490791bc3'}, {'reference': 'urn:uuid:8c092a56-d66d-c219-423b-da31a6388ace'}, {'reference': 'urn:uuid:ad9392f2-43f6-8848-8332-c102c0ff0340'}, {'reference': 'urn:uuid:a1b3f4a2-0342-f081-e58b-b34f7cb37469'}, {'reference': 'urn:uuid:252802b6-9cae-ea9a-ae7b-36a7ee50fcd4'}, {'reference': 'urn:uuid:473caaef-25ce-ab2d-9068-472076fe4235'}, {'reference': 'urn:uuid:63ff1421-019f-18a0-8d43-6733a8468f56'}, {'reference': 'urn:uuid:62504884-e3f0-5af3-8307-2daeaab989d7'}, {'reference': 'urn:uuid:b62d3389-83a8-a3eb-88b7-cf89ae842b05'}, {'reference': 'urn:uuid:42235c2c-780d-fd81-3a94-79e72abd44d8'}, {'reference': 'urn:uuid:719ee9b0-e223-4d73-86bf-47266a0f689f'}, {'reference': 'urn:uuid:82952047-e853-ff5c-c577-00a81909bdd3'}, {'reference': 'urn:uuid:eec8f1c3-9d1b-813e-d6f4-4b76370a37ef'}, {'reference': 'urn:uuid:ec616ced-ff7e-18c6-3ad9-3872241c97fa'}, {'reference': 'urn:uuid:4b7c4ef7-2850-b6f8-bc00-e2c702cdc9f1'}, {'reference': 'urn:uuid:4df2a70f-45fc-e9b0-fe17-1ca78f86500d'}, {'reference': 'urn:uuid:08a97d0d-29f6-30c2-1808-77c10fb84063'}, {'reference': 'urn:uuid:8df95df3-81cf-23f7-9e76-666e79a4c325'}, {'reference': 'urn:uuid:5f6620de-b44b-83aa-39f6-83a070b2e451'}, {'reference': 'urn:uuid:85e7e597-bc8d-c812-ff58-6a2b8c684525'}, {'reference': 'urn:uuid:c86f3049-3854-4eb5-3604-e4149b5853a6'}, {'reference': 'urn:uuid:b75ca798-f758-a13e-cfb7-3707b3c9e3d1'}, {'reference': 'urn:uuid:e4785c75-958d-00e4-e9fd-df2af3b8be98'}, {'reference': 'urn:uuid:c42845c8-fb39-a7e5-6509-bdc6f89067f2'}, {'reference': 'urn:uuid:20001618-567c-8a6b-ab1a-8959931c287a'}, {'reference': 'urn:uuid:e8bbd084-65f7-f3eb-cb2a-55e2e18efe2e'}, {'reference': 'urn:uuid:e6609e4f-fe27-bdab-beed-1ee40bb9bf80'}, {'reference': 'urn:uuid:29d17ee1-b1d6-b14b-d44e-4535c55844fe'}, {'reference': 'urn:uuid:8dac7aab-415d-3bee-15c2-0e65f7f85f8b'}, {'reference': 'urn:uuid:9a1bbd11-16d7-7cb5-1a1e-991ac240cda4'}, {'reference': 'urn:uuid:d73b7b58-2d8d-3924-db34-3279160cbf95'}, {'reference': 'urn:u ...
#   recorded : 2025-06-26T13:53:15.340+07:00
#   agent : [{'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/provenance-participant-type', 'code': 'author', 'display': 'Author'}], 'text': 'Author'}, 'who': {'reference': 'Practitioner?identifier=http://hl7.org/fhir/sid/us-npi|9999987297', 'display': 'Dr. Madelaine318 Walker122'}, 'onBehalfOf': {'reference': 'Organization?identifier=https://github.com/synthetichealth/synthea|af8566eb-8918-3ec7-ba44-92b6a2cf8097', 'display': 'NORTH SHORE MEDICAL CENTER INC'}}, {'type': {'coding': [{'system': 'http://hl7.org/fhir/us/core/CodeSystem/us-core-provenance-participant-type', 'code': 'transmitter', 'display': 'Transmitter'}], 'text': 'Transmitter'}, 'who': {'reference': 'Practitioner?identifier=http://hl7.org/fhir/sid/us-npi|9999987297', 'display': 'Dr. Madelaine318 Walker122'}, 'onBehalfOf': {'reference': 'Organization?identifier=https://github.com/synthetichealth/synthea|af8566eb-8918-3ec7-ba44-92b6a2cf8097', 'display': 'NORTH SHORE MEDICAL CENTER INC'}}]
# ====================

# %% [markdown]
# the relevant ones are: <br>
# patient <br>
# observation (has height, kg, etc. time issued)

# %%
data["entry"][report_type_to_index.get("Encounter")[0]]["resource"]
# Out:
# {'resourceType': 'Encounter',
#  'id': 'ec9b24ff-7b15-dd4d-3e00-345cecda85d2',
#  'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter']},
#  'identifier': [{'use': 'official',
#    'system': 'https://github.com/synthetichealth/synthea',
#    'value': 'ec9b24ff-7b15-dd4d-3e00-345cecda85d2'}],
#  'status': 'finished',
#  'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode',
#   'code': 'AMB'},
#  'type': [{'coding': [{'system': 'http://snomed.info/sct',
#      'code': '410620009',
#      'display': 'Well child visit (procedure)'}],
#    'text': 'Well child visit (procedure)'}],
#  'subject': {'reference': 'urn:uuid:4b40465b-ea68-fa3f-b224-d45cbc171913',
#   'display': 'Arnoldo445 Cameron381 Lueilwitz711'},
#  'participant': [{'type': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v3-ParticipationType',
#        'code': 'PPRF',
#        'display': 'primary performer'}],
#      'text': 'primary performer'}],
#    'period': {'start': '2014-11-20T13:53:15+07:00',
#     'end': '2014-11-20T14:08:15+07:00'},
#    'individual': {'reference': 'Practitioner?identifier=http://hl7.org/fhir/sid/us-npi|9999951491',
#     'display': 'Dr. Marcela739 CasÃ¡rez469'}}],
#  'period': {'start': '2014-11-20T13:53:15+07:00',
#   'end': '2014-11-20T14:08:15+07:00'},
#  'location': [{'location': {'reference': 'Location?identifier=https://github.com/synthetichealth/synthea|187ffa22-f0d4-3b78-9d80-cf3edbf9fe28',
#     'display': 'CAPE ANN MEDICAL CENTER LLC'}}],
#  'serviceProvider': {'reference': 'Organization?identifier=https://github.com/synthetichealth/synthea|c67ca7ed-4769-3b6c-a0a9-993f1227ff10',
#   'display': 'CAPE ANN MEDICAL CENTER LLC'}}

# %%
data["entry"][report_type_to_index.get("Encounter")[0]]["resource"]["participant"]
# Out:
# [{'type': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v3-ParticipationType',
#       'code': 'PPRF',
#       'display': 'primary performer'}],
#     'text': 'primary performer'}],
#   'period': {'start': '2014-11-20T13:53:15+07:00',
#    'end': '2014-11-20T14:08:15+07:00'},
#   'individual': {'reference': 'Practitioner?identifier=http://hl7.org/fhir/sid/us-npi|9999951491',
#    'display': 'Dr. Marcela739 CasÃ¡rez469'}}]

# %% [markdown]
# so take participant: period.start, period.end, location.display <br>
# code (AMB, EMER, etc.) <br>
# age

# %%
import pprint

for i in report_type_to_index.get("Encounter"):
    if data["entry"][i]["resource"]["class"]["code"] == "EMER":
        pprint.pprint(data["entry"][i]["resource"], indent=2)
# Out:
# { 'class': { 'code': 'EMER',
#              'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode'},
#   'id': '63ff1421-019f-18a0-8d43-6733a8468f56',
#   'identifier': [ { 'system': 'https://github.com/synthetichealth/synthea',
#                     'use': 'official',
#                     'value': '63ff1421-019f-18a0-8d43-6733a8468f56'}],
#   'location': [ { 'location': { 'display': 'BLUEBERRY HILL REHABILITATION AND '
#                                            'HEALTHCARE CTR',
#                                 'reference': 'Location?identifier=https://github.com/synthetichealth/synthea|b64fdbb3-9be7-317c-a90d-fa24b912c836'}}],
#   'meta': { 'profile': [ 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter']},
#   'participant': [ { 'individual': { 'display': 'Dr. Domonique463 '
#                                                 'Satterfield305',
#                                      'reference': 'Practitioner?identifier=http://hl7.org/fhir/sid/us-npi|9999881292'},
#                      'period': { 'end': '2016-09-11T14:53:15+07:00',
#                                  'start': '2016-09-11T13:53:15+07:00'},
#                      'type': [ { 'coding': [ { 'code': 'PPRF',
#                                                'display': 'primary performer',
#                                                'system': 'http://terminology.hl7.org/CodeSystem/v3-ParticipationType'}],
#                                  'text': 'primary performer'}]}],
#   'period': { 'end': '2016-09-11T14:53:15+07:00',
#               'start': '2016-09-11T13:53:15+07:00'},
#   'reasonCode': [ { 'coding': [ { 'code': '312608009',
#                                   'display': 'Laceration - injury (disorder)',
#                                   'system': 'http://snomed.info/sct'}]}],
#   'resourceType': 'Encounter',
#   'serviceProvider': { 'display': 'BLUEBERRY HILL REHABILITATION AND '
#                                   'HEALTHCARE CTR',
#                        'reference': 'Organization?identifier=https://github.com/synthetichealth/synthea|ee7fab6f-6438-394f-b1f2-3e452f8f055a'},
#   'status': 'finished',
#   'subject': { 'display': 'Arnoldo445 Cameron381 Lueilwitz711',
#                'reference': 'urn:uuid:4b40465b-ea68-fa3f-b224-d45cbc171913'},
#   'type': [ { 'coding': [ { 'code': '50849002',
#                             'display': 'Emergency room admission (procedure)',
#                             'system': 'http://snomed.info/sct'}],
#               'text': 'Emergency room admission (procedure)'}]}
